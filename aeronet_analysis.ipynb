# %% [markdown]
# # Aeronet Data Analysis
# Author: Andrew Loeppky
# Supervisor: Dr. Ian Mckendry
# Project: "Effects of wildfire smoke on Forest productivity in Central Canada"
#
#
# Reads in datasets and plots AOD at specified wavelengths, pulling from data_aq_scrub.py function library.
# Raw aeronet data can be found here:
#
# [Aeronet Data For Waskesiu](<https://aeronet.gsfc.nasa.gov/cgi-bin/data_display_aod_v3?site=Waskesiu&nachal=0&year=2020&aero_water=0&level=1&if_day=0&if_err=0&place_code=10&year_or_month=1>)
#
# To re-download data:
# - Select dataset, for example ```AOD level 1.0```
# - Save the file in the same folder that is running this program
# - Change the file extention from ```.lev10``` or ```.lev15``` to ```.csv``` (ignore warning)
# - Run this script to plot data

# %%
import data_aq_scrub
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd 
import scipy
import datetime
import time

# %%
### read in data

# test longer dataset
long_test = pd.read_csv('C:/Users/Owner/Wildfire_Smoke_Mckendry/data/Waskesiu_long_test10.csv', skiprows=6)

long_test.shape
# Out:
# (150444, 113)

# %%
long_test50 = long_test.iloc[0:(long_test.shape[0] // 50)]
data_aq_scrub.main(long_test50)
